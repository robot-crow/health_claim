# %%
import os
import pickle
import numpy as np
import pandas as pd

from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import OneHotEncoder
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.pipeline import Pipeline

import lightgbm as lgb

from sklearn.metrics import classification_report, confusion_matrix, log_loss, mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns

import shap

from sklearn.compose import ColumnTransformer
from model_header import DfExtractor, ModelHousing

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
demographics = ['age','sex']

illnesses= ['alzheimers','heart_failure','kidney_disease','cancer',
                'pulmonary_disease','depression','diabetes','ischemic_heart_disease',
                'osteoporosis','arthritis','stroke']

cover_info = ['in_cover_dur','out_cover_dur','carrier_cover_dur','drug_cover_dur',
             'in_cover_amt','out_cover_amt','in_excess_amt','out_excess_amt']

basic_features = demographics + illnesses + cover_info

# %%
status_target = ['claimed']
amount_target = ['total_claimed']
claimnum_target = ['no_of_claims']

# %%
all_feats = basic_features + status_target + amount_target + claimnum_target

# %%
state_num = 4211

# %%
cwd = os.getcwd() + '/'
models_path = cwd + 'models/'

if not os.path.exists(models_path):
    os.mkdir(models_path)

# %%
def read_data():
    df = pd.read_csv('data/gcm/gcm_data.csv',usecols=all_feats)
#     df = df[:100000]
    return df

# %%
class ModelTrainer():
    def __init__(self, params, cv_params):
        self.model_pipe = None
        
        self.mode = params.get('mode')
        self.features = params.get('features')
        self.ohe_feats = params.get('ohe_feats')
        self.imp_feats = params.get('imp_feats')
        self.y_target = params.get('y_target')
        
        self.cv_params = cv_params
        
    def split_data(self, df, y_target):
        X = df.drop(y_target, axis=1)[self.features]
        y = df[y_target]
        
        test_ratio = 0.2
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                            test_size=test_ratio, 
                                                            random_state=state_num)
        
        return X_train, y_train, X_test, y_test

    
    def build_pipeline(self):
        skf = StratifiedKFold(n_splits=3)
        
        if self.mode == 'class':
            grid_model = lgb.LGBMClassifier()
        elif self.mode == 'regr':
            grid_model = lgb.LGBMRegressor()
        else:
            raise ValueError('Specify mode as either """class""" or """regr""".')
            
        
        grid_search = GridSearchCV(estimator=grid_model, param_grid=self.cv_params, 
                                   cv=skf, refit=True, verbose=3)

        ohe = OneHotEncoder(handle_unknown='ignore',sparse_output=False)
        imp = IterativeImputer()
        
        df_extractor = DfExtractor()
        
        column_transformer = ColumnTransformer(transformers=[
            ('ohe', ohe, self.ohe_feats),
            ('imp', imp, self.imp_feats)
        ],remainder='passthrough').set_output(transform="pandas")

        
        model_pipe = Pipeline(steps=[
            ('column_transformer', column_transformer),
            ('df_extractor', df_extractor),
            ('grid_search', grid_search)
        ])

        return model_pipe
        
    def evaluate_model_class(self, y_test, y_pred, y_pred_prob):
        print(classification_report(y_test,y_pred))
        print('log loss:')
        print(log_loss(y_test, y_pred_prob))
        
        cm = confusion_matrix(y_test, y_pred)
        cmn = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        fig, ax = plt.subplots(figsize=(6,6))
        
        sns.heatmap(cmn, annot=True, fmt='.2f',cmap='flare')
        plt.ylabel('actual')
        plt.xlabel('predicted')
        plt.show(block=False)
        
    def evaluate_model_regr(self, y_test, y_pred):
        # visualizing in a plot
        x_ax = range(len(y_test))
        plt.figure(figsize=(12, 6))
        plt.plot(x_ax, y_test, label="original")
        plt.plot(x_ax, y_pred, label="predicted")
        plt.title("test and predicted data")
        plt.xlabel('X (records)')
        plt.ylabel('y (pred value)')
        plt.legend(loc='best',fancybox=True, shadow=True)
        plt.grid(True)
        plt.show(block=False)  
        
        # accuracy check
        mse = mean_squared_error(y_test, y_pred)
        rmse = mse**(0.5)
        print("MSE: %.2f" % mse)
        print("RMSE: %.2f" % rmse) 

    def construct_model(self,df):
        X_train, y_train, X_test, y_test = self.split_data(df, self.y_target)
        model_pipe = self.build_pipeline()
        model_pipe.fit(X_train, np.ravel(y_train))
        
        y_pred = model_pipe.predict(X_test)
        
        if self.mode == 'class':
            y_pred_prob = model_pipe.predict_proba(X_test)
            self.evaluate_model_class(y_test, y_pred, y_pred_prob)
        elif self.mode == 'regr':
            self.evaluate_model_regr(y_test, y_pred)
            
        
        self.model_pipe = model_pipe
        
    def get_model_housing(self, dump_to=None, mode=None):
        model_pipe = self.model_pipe
        model_pipe.named_steps['df_extractor'].data_frame = None
        
        mh = ModelHousing(self.model_pipe, self.mode)
        if dump_to != None:
            file = open(models_path + dump_to, 'wb')
            pickle.dump(mh, file)
            file.close()
            
        return mh

# %%
ohe_feats = ['sex'] + illnesses
imp_feats = [feat for feat in basic_features if feat not in ohe_feats]

# %%
df = read_data()

# %%
params_status = {
    'mode' : 'class',
    'features' : basic_features,
    'ohe_feats' : ohe_feats,
    'imp_feats' : imp_feats,
    'y_target' : status_target
}

cv_params_status = {
    'learning_rate' : ([0.03])
}

# %%
mt_status_class = ModelTrainer(params_status, cv_params_status)
mt_status_class.construct_model(df)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# [CV 1/3] END ................learning_rate=0.03;, score=0.903 total time=  14.3s
# [CV 2/3] END ................learning_rate=0.03;, score=0.902 total time=  12.8s
# [CV 3/3] END ................learning_rate=0.03;, score=0.903 total time=  12.8s
#               precision    recall  f1-score   support
#
#        False       0.74      0.92      0.82    329052
#         True       0.97      0.90      0.93   1013746
#
#     accuracy                           0.90   1342798
#    macro avg       0.86      0.91      0.88   1342798
# weighted avg       0.92      0.90      0.91   1342798
#
# log loss:
# 0.220920094223776

# %%
params_claimnum_regr = {
    'mode' : 'regr',
    'features' : basic_features,
    'ohe_feats' : ohe_feats,
    'imp_feats' : imp_feats,
    'y_target' : claimnum_target
}

cv_params_claimnum_regr = {
    'learning_rate' : ([0.03])
}

# %%
mt_claimnum_regr = ModelTrainer(params_claimnum_regr, cv_params_claimnum_regr)
mt_claimnum_regr.construct_model(df)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# The least populated class in y has only 2 members, which is less than n_splits=3.
# [CV 1/3] END ................learning_rate=0.03;, score=0.636 total time=  15.7s
# [CV 2/3] END ................learning_rate=0.03;, score=0.635 total time=  15.1s
# [CV 3/3] END ................learning_rate=0.03;, score=0.635 total time=  14.9s
# MSE: 27.61
# RMSE: 5.25

# %%
params_gross_regr = {
    'mode' : 'regr',
    'features' : basic_features,
    'ohe_feats' : ohe_feats,
    'imp_feats' : imp_feats,
    'y_target' : amount_target
}

cv_params_gross_regr = {
    'learning_rate' : ([0.03])
}

# %%
mt_gross_regr = ModelTrainer(params_gross_regr, cv_params_gross_regr)
mt_gross_regr.construct_model(df)
# Out:
# Fitting 3 folds for each of 1 candidates, totalling 3 fits
# The least populated class in y has only 1 members, which is less than n_splits=3.
# [CV 1/3] END ................learning_rate=0.03;, score=0.549 total time=  13.7s
# [CV 2/3] END ................learning_rate=0.03;, score=0.547 total time=  12.9s
# [CV 3/3] END ................learning_rate=0.03;, score=0.548 total time=  13.0s
# MSE: 106716907.97
# RMSE: 10330.39

# %%
mh_status = mt_status_class.get_model_housing(dump_to='status_housing.pkl')
mh_claimnum = mt_claimnum_regr.get_model_housing(dump_to='claimnum_housing.pkl')
mh_gross = mt_gross_regr.get_model_housing(dump_to='gross_housing.pkl')

# %%
test_df = df.iloc[0:10]
out_dict = mh_status.make_prediction(test_df)
out_dict
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
# {'row_0': {'y_pred': True,
#   'shap_vals': [('imp__out_cover_amt', 49.57266988789111),
#    ('imp__out_excess_amt', 36.65467086008925),
#    ('imp__out_cover_dur', 5.505840398455471),
#    ('ohe__ischemic_heart_disease_0', -2.721849410563382),
#    ('ohe__diabetes_0', -1.159570700277469),
#    ('imp__in_excess_amt', -1.0649218705911723),
#    ('imp__carrier_cover_dur', -0.9327613414997611),
#    ('imp__in_cover_dur', -0.7561602463017901),
#    ('imp__drug_cover_dur', 0.4796516761202606),
#    ('ohe__heart_failure_0', -0.366934857025881),
#    ('ohe__osteoporosis_0', -0.14975014900285863),
#    ('ohe__depression_0', -0.13905148684941254),
#    ('ohe__arthritis_0', -0.11801081722143583),
#    ('imp__age', 0.09896711798686249),
#    ('ohe__alzheimers_0', -0.07321897614504878),
#    ('ohe__kidney_disease_0', -0.07265472554537428),
#    ('ohe__pulmonary_disease_0', -0.059598538289404986),
#    ('ohe__cancer_0', -0.054716851711188466),
#    ('ohe__stroke_0', -0.010041355113589463),
#    ('ohe__sex_1', -0.008958733319275705),
#    ('ohe__sex_2', 0.0),
#    ('ohe__alzheimers_1', 0.0),
#    ('ohe__heart_failure_1', 0.0),
#    ('ohe__kidney_disease_1', 0.0),
#    ('ohe__cancer_1', 0.0),
#    ('ohe__pulmonary_disease_1', 0.0),
#    ('ohe__depression_1', 0.0),
#    ('ohe__diabetes_1', 0.0),
#    ('ohe__ischemic_heart_disease_1', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('ohe__arthritis_1', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__in_cover_amt', 0.0)]},
#  'row_1': {'y_pred': False,
#   'shap_vals': [('imp__out_cover_amt', 65.09480340930408),
#    ('ohe__ischemic_heart_disease_0', 8.76523037922377),
#    ('imp__out_cover_dur', -5.801480064780732),
#    ('imp__drug_cover_dur', 4.150171561855828),
#    ('ohe__diabetes_0', 3.642669831523894),
#    ('imp__in_excess_amt', 2.4251530475421372),
#    ('imp__in_cover_dur', 1.7542135332998383),
#    ('ohe__heart_failure_0', 1.7379136051689128),
#    ('imp__carrier_cover_dur', -1.433403726416401),
#    ('ohe__depression_0', 1.1702263702593512),
#    ('imp__age', 0.8770373208024371),
#    ('ohe__osteoporosis_0', 0.8679143762974075),
#    ('ohe__alzheimers_0', 0.7563021571166072),
#    ('ohe__arthritis_0', 0.46503528312436987),
#    ('imp__out_excess_amt', 0.4338599682233458),
#    ('ohe__kidney_disease_0', 0.20871110892000996),
#    ('ohe__cancer_0', 0.2000758321251408),
#    ('ohe__pulmonary_disease_0', 0.16902613546984613),
#    ('ohe__stroke_0', 0.032411213121087426),
#    ('ohe__sex_1', 0.014361075424789926),
#    ('ohe__sex_2', 0.0),
#    ('ohe__alzheimers_1', 0.0),
#    ('ohe__heart_failure_1', 0.0),
#    ('ohe__kidney_disease_1', 0.0),
#    ('ohe__cancer_1', 0.0),
#    ('ohe__pulmonary_disease_1', 0.0),
#    ('ohe__depression_1', 0.0),
#    ('ohe__diabetes_1', 0.0),
#    ('ohe__ischemic_heart_disease_1', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('ohe__arthritis_1', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__in_cover_amt', 0.0)]},
#  'row_2': {'y_pred': False,
#   'shap_vals': [('imp__out_cover_amt', 71.06790967943344),
#    ('ohe__ischemic_heart_disease_0', 8.262782380761896),
#    ('imp__out_cover_dur', -5.9250469110286375),
#    ('ohe__diabetes_0', 3.9461554812210884),
#    ('imp__in_excess_amt', 2.7164369157120283),
#    ('ohe__heart_failure_0', 1.6051399179827162),
#    ('ohe__depression_0', 1.171979155876195),
#    ('imp__in_cover_dur', 1.1047871283126594),
#    ('ohe__osteoporosis_0', 0.8510756725389088),
#    ('ohe__alzheimers_0', 0.7264991755664274),
#    ('ohe__arthritis_0', 0.5033024140033111),
#    ('imp__out_excess_amt', 0.4738164863093355),
#    ('imp__drug_cover_dur', -0.4245177376879313),
#    ('imp__carrier_cover_dur', -0.3611800622479057),
#    ('ohe__kidney_disease_0', 0.2642966956724228),
#    ('ohe__pulmonary_disease_0', 0.20193521251936192),
#    ('ohe__cancer_0', 0.19157495068468422),
#    ('imp__age', 0.14970804227611975),
#    ('ohe__stroke_0', 0.03761699981626025),
#    ('ohe__sex_1', -0.014238980348668892),
#    ('ohe__sex_2', 0.0),
#    ('ohe__alzheimers_1', 0.0),
#    ('ohe__heart_failure_1', 0.0),
#    ('ohe__kidney_disease_1', 0.0),
#    ('ohe__cancer_1', 0.0),
#    ('ohe__pulmonary_disease_1', 0.0),
#    ('ohe__depression_1', 0.0),
#    ('ohe__diabetes_1', 0.0),
#    ('ohe__ischemic_heart_disease_1', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('ohe__arthritis_1', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__in_cover_amt', 0.0)]},
#  'row_3': {'y_pred': False,
#   'shap_vals': [('imp__out_cover_amt', 63.83824985164013),
#    ('imp__out_cover_dur', 9.44689780006358),
#    ('ohe__ischemic_heart_disease_0', 8.387671266905459),
#    ('imp__in_cover_dur', -8.13480052705557),
#    ('ohe__diabetes_0', 3.268777253128897),
#    ('imp__in_excess_amt', 1.639394663012819),
#    ('ohe__heart_failure_0', 1.2616229256561762),
#    ('imp__carrier_cover_dur', -0.9154717056383401),
#    ('imp__age', -0.7064342434405273),
#    ('ohe__depression_0', 0.46781574828671946),
#    ('imp__drug_cover_dur', 0.3801541228512939),
#    ('ohe__alzheimers_0', 0.3517265587337843),
#    ('ohe__sex_1', 0.3143510201906675),
#    ('ohe__osteoporosis_0', 0.3009875190185085),
#    ('ohe__arthritis_0', 0.1720996873428324),
#    ('imp__out_excess_amt', 0.1636990574888919),
#    ('ohe__kidney_disease_0', 0.09902126067443184),
#    ('ohe__pulmonary_disease_0', 0.07442152583210615),
#    ('ohe__cancer_0', 0.06545144100226873),
#    ('ohe__stroke_0', 0.010951822036978752),
#    ('ohe__sex_2', 0.0),
#    ('ohe__alzheimers_1', 0.0),
#    ('ohe__heart_failure_1', 0.0),
#    ('ohe__kidney_disease_1', 0.0),
#    ('ohe__cancer_1', 0.0),
#    ('ohe__pulmonary_disease_1', 0.0),
#    ('ohe__depression_1', 0.0),
#    ('ohe__diabetes_1', 0.0),
#    ('ohe__ischemic_heart_disease_1', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('ohe__arthritis_1', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__in_cover_amt', 0.0)]},
#  'row_4': {'y_pred': True,
#   'shap_vals': [('imp__out_cover_amt', 52.21021209917118),
#    ('imp__out_excess_amt', 28.573933678711665),
#    ('ohe__osteoporosis_0', 6.286649600942891),
#    ('imp__out_cover_dur', 5.186276180832436),
#    ('ohe__ischemic_heart_disease_0', -2.856214573347265),
#    ('imp__in_cover_dur', -1.1203966859662626),
#    ('ohe__diabetes_0', -1.0675330653845956),
#    ('imp__in_excess_amt', -1.0211832741048894),
#    ('imp__drug_cover_dur', -0.5111524625819541),
#    ('ohe__heart_failure_0', -0.3666661638775648),
#    ('imp__carrier_cover_dur', 0.2292647680285393),
#    ('ohe__depression_0', -0.1234710371771213),
#    ('imp__age', 0.11397409475728097),
#    ('ohe__arthritis_0', -0.09155443931918927),
#    ('ohe__alzheimers_0', -0.07664528272559629),
#    ('ohe__kidney_disease_0', -0.05579296715540624),
#    ('ohe__pulmonary_disease_0', -0.047912977906172084),
#    ('ohe__cancer_0', -0.0435698906704697),
#    ('ohe__sex_1', -0.010029078581423162),
#    ('ohe__stroke_0', -0.007567678758084087),
#    ('ohe__sex_2', 0.0),
#    ('ohe__alzheimers_1', 0.0),
#    ('ohe__heart_failure_1', 0.0),
#    ('ohe__kidney_disease_1', 0.0),
#    ('ohe__cancer_1', 0.0),
#    ('ohe__pulmonary_disease_1', 0.0),
#    ('ohe__depression_1', 0.0),
#    ('ohe__diabetes_1', 0.0),
#    ('ohe__ischemic_heart_disease_1', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('ohe__arthritis_1', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__in_cover_amt', 0.0)]},
#  'row_5': {'y_pred': False,
#   'shap_vals': [('imp__out_cover_amt', 64.71073491109827),
#    ('imp__out_cover_dur', 8.53544631671574),
#    ('ohe__ischemic_heart_disease_0', 8.519139573392799),
#    ('imp__in_cover_dur', -8.010398875911688),
#    ('ohe__diabetes_0', 3.31750258140813),
#    ('imp__in_excess_amt', 1.6642617106659299),
#    ('ohe__heart_failure_0', 1.2867745362596248),
#    ('imp__carrier_cover_dur', -0.9187313728275368),
#    ('imp__drug_cover_dur', 0.6092808143697912),
#    ('ohe__depression_0', 0.4792308038130412),
#    ('imp__age', -0.3630231502354244),
#    ('ohe__alzheimers_0', 0.36087726158942585),
#    ('ohe__sex_1', 0.317979767267526),
#    ('ohe__osteoporosis_0', 0.3099843139026719),
#    ('ohe__arthritis_0', 0.1753425159675648),
#    ('imp__out_excess_amt', 0.16671569942770675),
#    ('ohe__kidney_disease_0', 0.10087586480827646),
#    ('ohe__pulmonary_disease_0', 0.07565704277781193),
#    ('ohe__cancer_0', 0.06685409638732218),
#    ('ohe__stroke_0', 0.01118879117371579),
#    ('ohe__sex_2', 0.0),
#    ('ohe__alzheimers_1', 0.0),
#    ('ohe__heart_failure_1', 0.0),
#    ('ohe__kidney_disease_1', 0.0),
#    ('ohe__cancer_1', 0.0),
#    ('ohe__pulmonary_disease_1', 0.0),
#    ('ohe__depression_1', 0.0),
#    ('ohe__diabetes_1', 0.0),
#    ('ohe__ischemic_heart_disease_1', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('ohe__arthritis_1', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__in_cover_amt', 0.0)]},
#  'row_6': {'y_pred': True,
#   'shap_vals': [('imp__out_cover_amt', 45.059484278756834),
#    ('imp__out_excess_amt', 15.486670108220018),
#    ('ohe__ischemic_heart_disease_0', 10.327023916603954),
#    ('ohe__diabetes_0', 8.344718447077327),
#    ('ohe__arthritis_0', 4.756482664875049),
#    ('ohe__heart_failure_0', 3.8666520324391835),
#    ('ohe__kidney_disease_0', 3.382012498156909),
#    ('ohe__depression_0', 2.829132317422699),
#    ('imp__out_cover_dur', 2.5559511688333343),
#    ('imp__in_excess_amt', -2.1382571692599837),
#    ('imp__in_cover_dur', -0.7207902419012777),
#    ('imp__drug_cover_dur', -0.10599063956560975),
#    ('imp__carrier_cover_dur', 0.10540959846872591),
#    ('ohe__osteoporosis_0', -0.09412681348078203),
#    ('imp__age', 0.07642958954260394),
#    ('ohe__alzheimers_0', -0.06877765599373237),
#    ('ohe__pulmonary_disease_0', -0.038473266383088546),
#    ('ohe__cancer_0', -0.030237908075587922),
#    ('ohe__sex_1', -0.009078210560819028),
#    ('ohe__stroke_0', -0.004301474382479001),
#    ('ohe__sex_2', 0.0),
#    ('ohe__alzheimers_1', 0.0),
#    ('ohe__heart_failure_1', 0.0),
#    ('ohe__kidney_disease_1', 0.0),
#    ('ohe__cancer_1', 0.0),
#    ('ohe__pulmonary_disease_1', 0.0),
#    ('ohe__depression_1', 0.0),
#    ('ohe__diabetes_1', 0.0),
#    ('ohe__ischemic_heart_disease_1', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('ohe__arthritis_1', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__in_cover_amt', 0.0)]},
#  'row_7': {'y_pred': True,
#   'shap_vals': [('imp__out_cover_amt', 52.64494795353279),
#    ('imp__out_excess_amt', 28.701037203399522),
#    ('ohe__osteoporosis_0', 6.1447618109164),
#    ('imp__out_cover_dur', 5.283058518807696),
#    ('ohe__ischemic_heart_disease_0', -2.8683660142265897),
#    ('ohe__diabetes_0', -1.0730363655849775),
#    ('imp__in_excess_amt', -1.0323472043714472),
#    ('imp__in_cover_dur', -0.7350750391784657),
#    ('ohe__heart_failure_0', -0.36654412569532574),
#    ('imp__drug_cover_dur', -0.3168169821297583),
#    ('imp__carrier_cover_dur', 0.24136162944849285),
#    ('imp__age', 0.1395974596941471),
#    ('ohe__depression_0', -0.12085150549709178),
#    ('ohe__arthritis_0', -0.0917295973332098),
#    ('ohe__alzheimers_0', -0.07477963801498469),
#    ('ohe__kidney_disease_0', -0.05615066567261572),
#    ('ohe__pulmonary_disease_0', -0.048223084894871766),
#    ('ohe__cancer_0', -0.04351435586344525),
#    ('ohe__sex_1', -0.010159609655461166),
#    ('ohe__stroke_0', -0.0076412360827125825),
#    ('ohe__sex_2', 0.0),
#    ('ohe__alzheimers_1', 0.0),
#    ('ohe__heart_failure_1', 0.0),
#    ('ohe__kidney_disease_1', 0.0),
#    ('ohe__cancer_1', 0.0),
#    ('ohe__pulmonary_disease_1', 0.0),
#    ('ohe__depression_1', 0.0),
#    ('ohe__diabetes_1', 0.0),
#    ('ohe__ischemic_heart_disease_1', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('ohe__arthritis_1', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__in_cover_amt', 0.0)]},
#  'row_8': {'y_pred': False,
#   'shap_vals': [('imp__out_cover_amt', 63.7885903677209),
#    ('imp__out_cover_dur', 8.475816865298716),
#    ('imp__in_cover_dur', -8.450085641164561),
#    ('ohe__ischemic_heart_disease_0', 8.426823084603136),
#    ('ohe__diabetes_0', 3.26667814575539),
#    ('imp__in_excess_amt', 1.6311432602553033),
#    ('ohe__heart_failure_0', 1.2364501441961337),
#    ('imp__carrier_cover_dur', -0.9004892812636969),
#    ('imp__age', -0.8996647859973386),
#    ('imp__drug_cover_dur', 0.7721618801560969),
#    ('ohe__depression_0', 0.4731417744196809),
#    ('ohe__sex_1', -0.43685604748064283),
#    ('ohe__alzheimers_0', 0.3510056114047608),
#    ('ohe__osteoporosis_0', 0.30319558540292735),
#    ('ohe__arthritis_0', 0.17270171840564935),
#    ('imp__out_excess_amt', 0.16461071816791592),
#    ('ohe__kidney_disease_0', 0.09912138862322752),
#    ('ohe__pulmonary_disease_0', 0.07467029019820588),
#    ('ohe__cancer_0', 0.06580058481849549),
#    ('ohe__stroke_0', 0.01099282466723193),
#    ('ohe__sex_2', 0.0),
#    ('ohe__alzheimers_1', 0.0),
#    ('ohe__heart_failure_1', 0.0),
#    ('ohe__kidney_disease_1', 0.0),
#    ('ohe__cancer_1', 0.0),
#    ('ohe__pulmonary_disease_1', 0.0),
#    ('ohe__depression_1', 0.0),
#    ('ohe__diabetes_1', 0.0),
#    ('ohe__ischemic_heart_disease_1', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('ohe__arthritis_1', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__in_cover_amt', 0.0)]},
#  'row_9': {'y_pred': False,
#   'shap_vals': [('imp__out_cover_amt', 68.61017142761429),
#    ('ohe__ischemic_heart_disease_0', 8.039699284107025),
#    ('imp__out_cover_dur', -5.531911192147315),
#    ('ohe__diabetes_0', 3.854390239672345),
#    ('imp__in_excess_amt', 2.621743702778156),
#    ('imp__drug_cover_dur', -2.3489451357317654),
#    ('imp__carrier_cover_dur', 1.8744970684983295),
#    ('ohe__heart_failure_0', 1.5741713572930167),
#    ('ohe__depression_0', 1.140829635574373),
#    ('imp__in_cover_dur', 0.9372561529559527),
#    ('ohe__osteoporosis_0', 0.831125065447485),
#    ('ohe__alzheimers_0', 0.7100104786275788),
#    ('ohe__arthritis_0', 0.4951084175528606),
#    ('imp__out_excess_amt', 0.45821292759161425),
#    ('imp__age', 0.27752004275515485),
#    ('ohe__kidney_disease_0', 0.25807499484740565),
#    ('ohe__pulmonary_disease_0', 0.19702040097373283),
#    ('ohe__cancer_0', 0.1877744143729584),
#    ('ohe__stroke_0', 0.037159318436180734),
#    ('ohe__sex_1', -0.01437874302246329),
#    ('ohe__sex_2', 0.0),
#    ('ohe__alzheimers_1', 0.0),
#    ('ohe__heart_failure_1', 0.0),
#    ('ohe__kidney_disease_1', 0.0),
#    ('ohe__cancer_1', 0.0),
#    ('ohe__pulmonary_disease_1', 0.0),
#    ('ohe__depression_1', 0.0),
#    ('ohe__diabetes_1', 0.0),
#    ('ohe__ischemic_heart_disease_1', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('ohe__arthritis_1', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__in_cover_amt', 0.0)]}}

# %%
test_df = df.iloc[0:10]
out_dict = mh_claimnum.make_prediction(test_df)
out_dict
# Out:
# {'row_0': {'y_pred': 4.452922664532594,
#   'shap_vals': [('imp__out_excess_amt', -26.540580117771395),
#    ('imp__out_cover_amt', -20.021666000874433),
#    ('ohe__heart_failure_0', -8.10811196857642),
#    ('ohe__ischemic_heart_disease_0', -6.706134479752812),
#    ('ohe__diabetes_0', -6.702626760838036),
#    ('ohe__kidney_disease_0', -5.62149960888352),
#    ('ohe__depression_0', -4.6632857793204305),
#    ('ohe__diabetes_1', -3.6901764390856893),
#    ('imp__in_excess_amt', -3.183427940426649),
#    ('ohe__ischemic_heart_disease_1', -2.9585449090529825),
#    ('ohe__alzheimers_0', -2.4770080623114263),
#    ('ohe__pulmonary_disease_0', -1.9598483624974614),
#    ('imp__drug_cover_dur', 1.9217033210593462),
#    ('imp__out_cover_dur', 1.1754756334300758),
#    ('imp__age', 0.8868741090245837),
#    ('ohe__heart_failure_1', -0.5801265242857925),
#    ('ohe__arthritis_0', -0.5462662806344278),
#    ('ohe__osteoporosis_0', -0.4193847575730425),
#    ('ohe__pulmonary_disease_1', -0.37980463954745547),
#    ('ohe__cancer_0', -0.36283342850942124),
#    ('ohe__alzheimers_1', -0.24959910849992342),
#    ('ohe__depression_1', -0.23604393397205894),
#    ('ohe__osteoporosis_1', -0.1800603259668401),
#    ('ohe__arthritis_1', -0.17773032675115882),
#    ('ohe__cancer_1', -0.13018276778702637),
#    ('ohe__kidney_disease_1', -0.08151648027544985),
#    ('imp__in_cover_dur', 0.033994829241374654),
#    ('imp__in_cover_amt', 0.005493104050763918),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__stroke_0', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_1': {'y_pred': 1.1664061658464695,
#   'shap_vals': [('imp__out_cover_amt', -52.443439934797894),
#    ('imp__out_excess_amt', -18.36198938497899),
#    ('imp__drug_cover_dur', -3.6796525705392527),
#    ('ohe__ischemic_heart_disease_0', -3.6544642761434516),
#    ('ohe__heart_failure_0', -3.489570986284433),
#    ('ohe__diabetes_0', -2.58587182689765),
#    ('ohe__ischemic_heart_disease_1', -2.4687358221952804),
#    ('ohe__kidney_disease_0', -2.266045844182309),
#    ('ohe__depression_0', -2.0427066022314047),
#    ('ohe__diabetes_1', -1.8858975717689872),
#    ('imp__in_excess_amt', -1.5377556628123383),
#    ('ohe__alzheimers_0', -1.1519260461992218),
#    ('ohe__pulmonary_disease_0', -0.9886376520912165),
#    ('imp__out_cover_dur', 0.9338225595791928),
#    ('ohe__heart_failure_1', -0.534325826745492),
#    ('ohe__arthritis_0', -0.38427667673803084),
#    ('ohe__osteoporosis_0', -0.32972749471990515),
#    ('ohe__cancer_0', -0.22297307788121373),
#    ('ohe__pulmonary_disease_1', -0.20238370354533752),
#    ('imp__age', -0.19158184808769177),
#    ('ohe__depression_1', -0.1542172546140625),
#    ('ohe__alzheimers_1', -0.1253595780729709),
#    ('ohe__arthritis_1', -0.11890714905798165),
#    ('ohe__osteoporosis_1', -0.1087931531278513),
#    ('ohe__cancer_1', -0.07331712710327078),
#    ('ohe__kidney_disease_1', -0.04089313357570106),
#    ('imp__in_cover_dur', 0.021080557892791233),
#    ('imp__in_cover_amt', 0.0016466781360690713),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__stroke_0', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_2': {'y_pred': 1.3117333673615734,
#   'shap_vals': [('imp__out_cover_amt', -52.34117935350966),
#    ('imp__out_excess_amt', -19.032929984722127),
#    ('ohe__ischemic_heart_disease_0', -3.89538575011533),
#    ('ohe__heart_failure_0', -3.80879524328787),
#    ('ohe__diabetes_0', -2.9602354034534875),
#    ('ohe__ischemic_heart_disease_1', -2.567957573551923),
#    ('ohe__kidney_disease_0', -2.432046300060709),
#    ('ohe__depression_0', -2.300559392828541),
#    ('ohe__diabetes_1', -1.9979530902485536),
#    ('imp__in_excess_amt', -1.4835768001030645),
#    ('ohe__alzheimers_0', -1.306225505963507),
#    ('imp__drug_cover_dur', 1.2928510552309365),
#    ('ohe__pulmonary_disease_0', -0.9741646312995462),
#    ('imp__out_cover_dur', 0.9448420826391395),
#    ('ohe__heart_failure_1', -0.6304576344465892),
#    ('ohe__arthritis_0', -0.3554217066497856),
#    ('ohe__osteoporosis_0', -0.3306699724933182),
#    ('ohe__cancer_0', -0.2138114686188183),
#    ('ohe__depression_1', -0.20273629732888324),
#    ('ohe__pulmonary_disease_1', -0.19439322902517386),
#    ('ohe__alzheimers_1', -0.1835147249761153),
#    ('imp__age', -0.14838734391172448),
#    ('ohe__arthritis_1', -0.11714572401926833),
#    ('ohe__osteoporosis_1', -0.10839113188362787),
#    ('ohe__cancer_1', -0.08351991924790353),
#    ('ohe__kidney_disease_1', -0.07267417937772737),
#    ('imp__in_cover_dur', 0.01736299708437533),
#    ('imp__in_cover_amt', 0.0028115039223101414),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__stroke_0', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_3': {'y_pred': 0.7829728116250214,
#   'shap_vals': [('imp__out_cover_amt', -50.70955859376386),
#    ('imp__out_excess_amt', -16.934890414159128),
#    ('ohe__ischemic_heart_disease_0', -3.659644409626444),
#    ('ohe__heart_failure_0', -3.466038696321298),
#    ('imp__drug_cover_dur', -3.4473915834128457),
#    ('imp__out_cover_dur', -3.269760745973941),
#    ('ohe__diabetes_0', -2.58923278044581),
#    ('ohe__ischemic_heart_disease_1', -2.4324609078328),
#    ('ohe__kidney_disease_0', -2.262387152661428),
#    ('ohe__depression_0', -2.0583200757463773),
#    ('ohe__diabetes_1', -1.9499261989984848),
#    ('imp__in_excess_amt', -1.4715294821165001),
#    ('imp__in_cover_dur', -1.2163718306451516),
#    ('ohe__alzheimers_0', -1.1967852626114124),
#    ('ohe__pulmonary_disease_0', -0.9856065881360258),
#    ('ohe__heart_failure_1', -0.5391374053469741),
#    ('ohe__arthritis_0', -0.35514838702240276),
#    ('ohe__osteoporosis_0', -0.3042328423624746),
#    ('ohe__cancer_0', -0.21160643783100422),
#    ('ohe__pulmonary_disease_1', -0.20006064584846117),
#    ('ohe__depression_1', -0.15734810050817805),
#    ('imp__age', -0.13032000393418244),
#    ('ohe__alzheimers_1', -0.12647171729700973),
#    ('ohe__osteoporosis_1', -0.10734232601309038),
#    ('ohe__arthritis_1', -0.0988116065764577),
#    ('ohe__cancer_1', -0.07554162378938657),
#    ('ohe__kidney_disease_1', -0.04249118112354587),
#    ('imp__in_cover_amt', 0.0015829998953211157),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__stroke_0', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_4': {'y_pred': 4.86185786127515,
#   'shap_vals': [('imp__out_cover_amt', -30.3389270213574),
#    ('ohe__osteoporosis_0', 9.17196315103471),
#    ('imp__out_excess_amt', -8.396018014092915),
#    ('ohe__heart_failure_0', -7.175941662642769),
#    ('ohe__ischemic_heart_disease_0', -5.579965323470851),
#    ('imp__drug_cover_dur', -5.574858416713419),
#    ('ohe__kidney_disease_0', -5.318836349086356),
#    ('ohe__diabetes_0', -5.306751785963126),
#    ('ohe__depression_0', -3.7303307896084026),
#    ('imp__in_excess_amt', -3.1331592084954423),
#    ('ohe__diabetes_1', -3.000769006020369),
#    ('ohe__osteoporosis_1', 2.789496681967953),
#    ('ohe__ischemic_heart_disease_1', -2.520570814864577),
#    ('ohe__alzheimers_0', -2.1094959237924513),
#    ('ohe__pulmonary_disease_0', -1.8842301787643136),
#    ('imp__out_cover_dur', 0.9626108860662471),
#    ('ohe__heart_failure_1', -0.5536169107225509),
#    ('ohe__arthritis_0', -0.49029245761682455),
#    ('ohe__pulmonary_disease_1', -0.4795420068852696),
#    ('ohe__cancer_0', -0.37253327362051036),
#    ('imp__age', -0.31718074172636823),
#    ('ohe__arthritis_1', -0.21827090653900796),
#    ('ohe__depression_1', -0.15654525095038269),
#    ('ohe__cancer_1', -0.13867707246977898),
#    ('ohe__alzheimers_1', -0.13387215385621526),
#    ('imp__in_cover_dur', 0.10816746239412718),
#    ('ohe__kidney_disease_1', -0.03440088664328095),
#    ('imp__in_cover_amt', 0.0029756626343852934),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__stroke_0', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_5': {'y_pred': 0.7829728116250214,
#   'shap_vals': [('imp__out_cover_amt', -50.70955859376386),
#    ('imp__out_excess_amt', -16.934890414159128),
#    ('ohe__ischemic_heart_disease_0', -3.659644409626444),
#    ('ohe__heart_failure_0', -3.466038696321298),
#    ('imp__drug_cover_dur', -3.4473915834128457),
#    ('imp__out_cover_dur', -3.269760745973941),
#    ('ohe__diabetes_0', -2.58923278044581),
#    ('ohe__ischemic_heart_disease_1', -2.4324609078328),
#    ('ohe__kidney_disease_0', -2.262387152661428),
#    ('ohe__depression_0', -2.0583200757463773),
#    ('ohe__diabetes_1', -1.9499261989984848),
#    ('imp__in_excess_amt', -1.4715294821165001),
#    ('imp__in_cover_dur', -1.2163718306451516),
#    ('ohe__alzheimers_0', -1.1967852626114124),
#    ('ohe__pulmonary_disease_0', -0.9856065881360258),
#    ('ohe__heart_failure_1', -0.5391374053469741),
#    ('ohe__arthritis_0', -0.35514838702240276),
#    ('ohe__osteoporosis_0', -0.3042328423624746),
#    ('ohe__cancer_0', -0.21160643783100422),
#    ('ohe__pulmonary_disease_1', -0.20006064584846117),
#    ('ohe__depression_1', -0.15734810050817805),
#    ('imp__age', -0.13032000393418244),
#    ('ohe__alzheimers_1', -0.12647171729700973),
#    ('ohe__osteoporosis_1', -0.10734232601309038),
#    ('ohe__arthritis_1', -0.0988116065764577),
#    ('ohe__cancer_1', -0.07554162378938657),
#    ('ohe__kidney_disease_1', -0.04249118112354587),
#    ('imp__in_cover_amt', 0.0015829998953211157),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__stroke_0', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_6': {'y_pred': 16.248934818737645,
#   'shap_vals': [('imp__out_cover_amt', 46.961496386935316),
#    ('imp__out_excess_amt', 11.816115094279073),
#    ('ohe__kidney_disease_0', 9.424690910363312),
#    ('ohe__heart_failure_0', 5.771020952692892),
#    ('ohe__depression_0', 4.761531464551647),
#    ('imp__drug_cover_dur', -4.644546112680318),
#    ('imp__in_excess_amt', -2.875793790212803),
#    ('ohe__diabetes_0', 2.593072175497208),
#    ('ohe__diabetes_1', 2.093505370513025),
#    ('ohe__ischemic_heart_disease_0', 1.9060956386737196),
#    ('ohe__ischemic_heart_disease_1', 1.4814585915955394),
#    ('ohe__arthritis_0', 1.3333923425005871),
#    ('ohe__pulmonary_disease_0', -1.3193262735755653),
#    ('ohe__heart_failure_1', 0.8510444149351302),
#    ('ohe__alzheimers_0', -0.6902500590373144),
#    ('ohe__arthritis_1', 0.3878077412201025),
#    ('ohe__depression_1', 0.2514451234474645),
#    ('ohe__pulmonary_disease_1', -0.2239133354407038),
#    ('ohe__kidney_disease_1', 0.16360924378726074),
#    ('imp__age', 0.11246744570722048),
#    ('imp__out_cover_dur', 0.10399896080661196),
#    ('ohe__cancer_0', -0.08384405610837119),
#    ('ohe__alzheimers_1', -0.06378814071400261),
#    ('ohe__cancer_1', -0.030921395228810874),
#    ('ohe__osteoporosis_0', -0.023395601785397332),
#    ('imp__in_cover_dur', 0.021317896625946173),
#    ('ohe__osteoporosis_1', -0.0072880761420243976),
#    ('imp__in_cover_amt', 0.0028634049426281877),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__stroke_0', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_7': {'y_pred': 7.682421446322988,
#   'shap_vals': [('imp__out_cover_amt', 26.44808366650854),
#    ('imp__out_excess_amt', 19.263821154719647),
#    ('ohe__heart_failure_0', -6.596285499922322),
#    ('imp__drug_cover_dur', -6.427887165695628),
#    ('ohe__ischemic_heart_disease_0', -5.604447847331578),
#    ('ohe__kidney_disease_0', -5.35649878214069),
#    ('ohe__osteoporosis_0', 4.774299495932102),
#    ('ohe__diabetes_0', -4.280464304731182),
#    ('ohe__depression_0', -3.661669142855655),
#    ('ohe__diabetes_1', -3.205477265212011),
#    ('imp__in_excess_amt', -3.0469808152093125),
#    ('ohe__pulmonary_disease_0', -2.4073670467307897),
#    ('ohe__ischemic_heart_disease_1', -2.3157793918080856),
#    ('ohe__alzheimers_0', -1.6465186939614507),
#    ('ohe__osteoporosis_1', 1.421584454363011),
#    ('ohe__heart_failure_1', -0.6380019827067419),
#    ('ohe__arthritis_0', -0.5726750030474811),
#    ('ohe__pulmonary_disease_1', -0.48480303771347305),
#    ('imp__out_cover_dur', -0.45795606960989976),
#    ('ohe__cancer_0', -0.35112410754466283),
#    ('imp__age', -0.21398888192429438),
#    ('ohe__arthritis_1', -0.20077269394233244),
#    ('ohe__depression_1', -0.17763057932527218),
#    ('ohe__cancer_1', -0.15228025056123914),
#    ('imp__in_cover_dur', 0.13913859612841403),
#    ('ohe__alzheimers_1', -0.12634894486219728),
#    ('ohe__kidney_disease_1', -0.02564113142069397),
#    ('imp__in_cover_amt', 0.0024739940913038835),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__stroke_0', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_8': {'y_pred': 0.7829728116250214,
#   'shap_vals': [('imp__out_cover_amt', -50.70955859376386),
#    ('imp__out_excess_amt', -16.966177455145377),
#    ('ohe__ischemic_heart_disease_0', -3.659644409626443),
#    ('ohe__heart_failure_0', -3.4849952633791133),
#    ('imp__drug_cover_dur', -3.463633033942731),
#    ('imp__out_cover_dur', -3.269760745973941),
#    ('ohe__diabetes_0', -2.5892327804458097),
#    ('ohe__ischemic_heart_disease_1', -2.4324609078327994),
#    ('ohe__kidney_disease_0', -2.258382321875689),
#    ('ohe__depression_0', -2.054420969503942),
#    ('ohe__diabetes_1', -1.9499261989984844),
#    ('imp__in_excess_amt', -1.4696653079082163),
#    ('imp__in_cover_dur', -1.2407251476384176),
#    ('ohe__alzheimers_0', -1.1953361178743798),
#    ('ohe__pulmonary_disease_0', -0.9844300764863891),
#    ('ohe__heart_failure_1', -0.539137405346974),
#    ('ohe__arthritis_0', -0.3551483870224027),
#    ('ohe__osteoporosis_0', -0.30423284236247455),
#    ('ohe__cancer_0', -0.2106070460726298),
#    ('ohe__pulmonary_disease_1', -0.20006064584846112),
#    ('ohe__depression_1', -0.15734810050817802),
#    ('ohe__alzheimers_1', -0.1264717172970097),
#    ('ohe__osteoporosis_1', -0.10734232601309036),
#    ('ohe__arthritis_1', -0.0978619420462776),
#    ('ohe__cancer_1', -0.07554162378938656),
#    ('imp__age', -0.053824452278647905),
#    ('ohe__kidney_disease_1', -0.04249118112354587),
#    ('imp__in_cover_amt', 0.0015829998953211153),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__stroke_0', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_9': {'y_pred': 1.3117333673615734,
#   'shap_vals': [('imp__out_cover_amt', -52.34117935350966),
#    ('imp__out_excess_amt', -19.032929984722127),
#    ('ohe__ischemic_heart_disease_0', -3.89538575011533),
#    ('ohe__heart_failure_0', -3.80879524328787),
#    ('ohe__diabetes_0', -2.9602354034534875),
#    ('ohe__ischemic_heart_disease_1', -2.567957573551923),
#    ('ohe__kidney_disease_0', -2.432046300060709),
#    ('ohe__depression_0', -2.300559392828541),
#    ('ohe__diabetes_1', -1.9979530902485536),
#    ('imp__in_excess_amt', -1.4835768001030645),
#    ('ohe__alzheimers_0', -1.306225505963507),
#    ('imp__drug_cover_dur', 1.2928510552309365),
#    ('ohe__pulmonary_disease_0', -0.9741646312995462),
#    ('imp__out_cover_dur', 0.9448420826391395),
#    ('ohe__heart_failure_1', -0.6304576344465892),
#    ('ohe__arthritis_0', -0.3554217066497856),
#    ('ohe__osteoporosis_0', -0.3306699724933182),
#    ('ohe__cancer_0', -0.2138114686188183),
#    ('ohe__depression_1', -0.20273629732888324),
#    ('ohe__pulmonary_disease_1', -0.19439322902517386),
#    ('ohe__alzheimers_1', -0.1835147249761153),
#    ('imp__age', -0.14838734391172448),
#    ('ohe__arthritis_1', -0.11714572401926833),
#    ('ohe__osteoporosis_1', -0.10839113188362787),
#    ('ohe__cancer_1', -0.08351991924790353),
#    ('ohe__kidney_disease_1', -0.07267417937772737),
#    ('imp__in_cover_dur', 0.01736299708437533),
#    ('imp__in_cover_amt', 0.0028115039223101414),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__stroke_0', 0.0),
#    ('ohe__stroke_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]}}

# %%
test_df = df.iloc[0:10]
out_dict = mh_gross.make_prediction(test_df)
out_dict
# Out:
# {'row_0': {'y_pred': 2480.00827327404,
#   'shap_vals': [('imp__in_cover_amt', -31.71559747308774),
#    ('imp__out_cover_amt', -11.425921132585033),
#    ('ohe__kidney_disease_0', -9.79233682331906),
#    ('ohe__heart_failure_0', -8.601050680729683),
#    ('ohe__ischemic_heart_disease_0', -5.453012584771682),
#    ('imp__out_excess_amt', -4.453873680930715),
#    ('imp__age', 3.9535952447036644),
#    ('ohe__ischemic_heart_disease_1', -3.807280484908925),
#    ('ohe__diabetes_0', -3.6358091416184535),
#    ('ohe__heart_failure_1', -3.0463014245825226),
#    ('ohe__diabetes_1', -2.5544642297053572),
#    ('ohe__pulmonary_disease_0', -2.3569697055076744),
#    ('ohe__alzheimers_0', -1.8762214947661493),
#    ('ohe__depression_0', -1.5832794189357648),
#    ('ohe__kidney_disease_1', -1.0367662506957114),
#    ('imp__in_excess_amt', -1.0310862859161738),
#    ('imp__out_cover_dur', 0.7245519559534261),
#    ('imp__drug_cover_dur', 0.6656464265393018),
#    ('ohe__depression_1', -0.5692984186668912),
#    ('ohe__arthritis_0', -0.34461448304388087),
#    ('ohe__stroke_0', -0.3026436765457163),
#    ('ohe__alzheimers_1', -0.29652201136162626),
#    ('ohe__pulmonary_disease_1', -0.24724930198243497),
#    ('ohe__cancer_1', -0.16460401029206947),
#    ('ohe__cancer_0', -0.1381515680959865),
#    ('ohe__arthritis_1', -0.1149474493506985),
#    ('ohe__stroke_1', -0.09176163149051461),
#    ('imp__in_cover_dur', -0.009674886919718259),
#    ('ohe__osteoporosis_0', 0.006768122993436573),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_1': {'y_pred': 1315.5950673364916,
#   'shap_vals': [('imp__in_cover_amt', -28.84096227254901),
#    ('imp__out_cover_amt', -20.127484025094525),
#    ('ohe__kidney_disease_0', -8.394018275623825),
#    ('ohe__heart_failure_0', -7.601533298898867),
#    ('ohe__ischemic_heart_disease_0', -5.675751180280077),
#    ('imp__out_excess_amt', -4.071079509415466),
#    ('ohe__ischemic_heart_disease_1', -3.898113149613515),
#    ('ohe__diabetes_0', -3.508729992852075),
#    ('ohe__heart_failure_1', -2.7072098748728854),
#    ('ohe__diabetes_1', -2.644408286778904),
#    ('ohe__pulmonary_disease_0', -2.189724121729614),
#    ('imp__drug_cover_dur', -1.681387023417643),
#    ('ohe__alzheimers_0', -1.621488316403319),
#    ('ohe__depression_0', -1.5652495696017443),
#    ('imp__age', -1.011667699765102),
#    ('imp__in_excess_amt', -0.9169831614042417),
#    ('ohe__kidney_disease_1', -0.7764038834551868),
#    ('imp__out_cover_dur', 0.5592393715507398),
#    ('ohe__depression_1', -0.5420034316475616),
#    ('ohe__arthritis_0', -0.36398904126601594),
#    ('ohe__stroke_0', -0.27573167170407864),
#    ('ohe__pulmonary_disease_1', -0.24105823781975697),
#    ('ohe__alzheimers_1', -0.23472647500140142),
#    ('ohe__cancer_1', -0.18085876013226374),
#    ('ohe__cancer_0', -0.14488610507890373),
#    ('ohe__arthritis_1', -0.13417715549657216),
#    ('ohe__stroke_1', -0.07827415645956527),
#    ('imp__in_cover_dur', -0.008703259189002558),
#    ('ohe__osteoporosis_0', 0.004158692898139885),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_2': {'y_pred': 1358.2750541390149,
#   'shap_vals': [('imp__in_cover_amt', -28.75208075486991),
#    ('imp__out_cover_amt', -20.13696285046054),
#    ('ohe__kidney_disease_0', -9.032229510581539),
#    ('ohe__heart_failure_0', -7.763860694433242),
#    ('ohe__ischemic_heart_disease_0', -5.720631430901482),
#    ('imp__out_excess_amt', -4.1013824523328815),
#    ('ohe__ischemic_heart_disease_1', -3.917475235394268),
#    ('ohe__diabetes_0', -3.48761170244434),
#    ('ohe__heart_failure_1', -2.7388070512593465),
#    ('ohe__diabetes_1', -2.640618800144198),
#    ('ohe__pulmonary_disease_0', -2.172330040929419),
#    ('ohe__alzheimers_0', -1.7555393666745134),
#    ('ohe__depression_0', -1.5786640696716068),
#    ('imp__age', -1.1574638144653016),
#    ('imp__in_excess_amt', -0.9671906954870418),
#    ('ohe__kidney_disease_1', -0.8840157087908865),
#    ('ohe__depression_1', -0.5641121001007023),
#    ('imp__out_cover_dur', 0.558437971050413),
#    ('imp__drug_cover_dur', 0.4090606019312229),
#    ('ohe__arthritis_0', -0.34798097612039663),
#    ('ohe__stroke_0', -0.28745451534893945),
#    ('ohe__pulmonary_disease_1', -0.23709248461771812),
#    ('ohe__alzheimers_1', -0.234390107563636),
#    ('ohe__cancer_1', -0.1779173207364211),
#    ('ohe__cancer_0', -0.14332078540882423),
#    ('ohe__arthritis_1', -0.1294747094982597),
#    ('ohe__stroke_1', -0.08912377113492656),
#    ('imp__in_cover_dur', -0.008690787255473988),
#    ('ohe__osteoporosis_0', 0.006079690392552094),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_3': {'y_pred': 1036.263579169156,
#   'shap_vals': [('imp__in_cover_amt', -28.018573083640565),
#    ('imp__out_cover_amt', -19.606262459954106),
#    ('ohe__kidney_disease_0', -8.157758889338524),
#    ('ohe__heart_failure_0', -7.422010142883679),
#    ('ohe__ischemic_heart_disease_0', -5.5843199931939225),
#    ('imp__out_excess_amt', -3.983961840007803),
#    ('ohe__ischemic_heart_disease_1', -3.966290183059673),
#    ('ohe__diabetes_0', -3.4764450831017557),
#    ('imp__out_cover_dur', -2.7917603883807063),
#    ('ohe__heart_failure_1', -2.681677978612332),
#    ('ohe__diabetes_1', -2.6103056854174325),
#    ('ohe__pulmonary_disease_0', -2.1267728193915136),
#    ('ohe__alzheimers_0', -1.6577419883518327),
#    ('imp__drug_cover_dur', -1.6253237647540573),
#    ('ohe__depression_0', -1.587719537471073),
#    ('imp__in_excess_amt', -0.8969254240290094),
#    ('imp__age', -0.8493063121050238),
#    ('ohe__kidney_disease_1', -0.750515892683684),
#    ('ohe__depression_1', -0.523931162644769),
#    ('ohe__arthritis_0', -0.3594056924952116),
#    ('ohe__stroke_0', -0.2679148814131652),
#    ('ohe__pulmonary_disease_1', -0.23105107264761512),
#    ('ohe__alzheimers_1', -0.22689988249181567),
#    ('ohe__cancer_1', -0.1767578747281952),
#    ('ohe__cancer_0', -0.14245171405625554),
#    ('ohe__arthritis_1', -0.1403819367971564),
#    ('ohe__stroke_1', -0.07566422536152054),
#    ('imp__in_cover_dur', 0.05785006329407156),
#    ('ohe__osteoporosis_0', 0.004020027693517975),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_4': {'y_pred': 2187.1527828619455,
#   'shap_vals': [('imp__in_cover_amt', -33.29870132289674),
#    ('imp__out_cover_amt', -12.043062707389199),
#    ('ohe__kidney_disease_0', -9.299654360542226),
#    ('ohe__heart_failure_0', -8.3958620797065),
#    ('ohe__ischemic_heart_disease_0', -5.49883809515263),
#    ('imp__out_excess_amt', -3.8917290430960323),
#    ('ohe__diabetes_0', -3.856589515494866),
#    ('ohe__ischemic_heart_disease_1', -3.613982214673451),
#    ('ohe__heart_failure_1', -3.1167025060418534),
#    ('ohe__diabetes_1', -2.668506588295626),
#    ('ohe__pulmonary_disease_0', -2.5164990050865788),
#    ('imp__drug_cover_dur', -1.9357676478713792),
#    ('ohe__alzheimers_0', -1.820072652263578),
#    ('ohe__depression_0', -1.7237083317677533),
#    ('imp__age', -1.174817259796951),
#    ('imp__in_excess_amt', -1.065019403109985),
#    ('ohe__kidney_disease_1', -0.9016129338401544),
#    ('imp__out_cover_dur', 0.6494267497206427),
#    ('ohe__depression_1', -0.5865402937187412),
#    ('ohe__arthritis_0', -0.42314897485633907),
#    ('ohe__stroke_0', -0.32030635887002196),
#    ('ohe__pulmonary_disease_1', -0.2799332018533798),
#    ('ohe__alzheimers_1', -0.2725803287255021),
#    ('ohe__cancer_1', -0.21002547875967054),
#    ('ohe__cancer_0', -0.16825158793838407),
#    ('ohe__arthritis_1', -0.15581562817952288),
#    ('ohe__stroke_1', -0.0908972679725723),
#    ('ohe__osteoporosis_0', -0.011841646560540837),
#    ('imp__in_cover_dur', -0.010106815819167392),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_5': {'y_pred': 1036.263579169156,
#   'shap_vals': [('imp__in_cover_amt', -28.018573083640565),
#    ('imp__out_cover_amt', -19.606262459954106),
#    ('ohe__kidney_disease_0', -8.157758889338524),
#    ('ohe__heart_failure_0', -7.422010142883679),
#    ('ohe__ischemic_heart_disease_0', -5.5843199931939225),
#    ('imp__out_excess_amt', -3.983961840007803),
#    ('ohe__ischemic_heart_disease_1', -3.966290183059673),
#    ('ohe__diabetes_0', -3.4764450831017557),
#    ('imp__out_cover_dur', -2.7917603883807063),
#    ('ohe__heart_failure_1', -2.681677978612332),
#    ('ohe__diabetes_1', -2.6103056854174325),
#    ('ohe__pulmonary_disease_0', -2.1267728193915136),
#    ('ohe__alzheimers_0', -1.6577419883518327),
#    ('imp__drug_cover_dur', -1.6253237647540573),
#    ('ohe__depression_0', -1.587719537471073),
#    ('imp__in_excess_amt', -0.8969254240290094),
#    ('imp__age', -0.8493063121050238),
#    ('ohe__kidney_disease_1', -0.750515892683684),
#    ('ohe__depression_1', -0.523931162644769),
#    ('ohe__arthritis_0', -0.3594056924952116),
#    ('ohe__stroke_0', -0.2679148814131652),
#    ('ohe__pulmonary_disease_1', -0.23105107264761512),
#    ('ohe__alzheimers_1', -0.22689988249181567),
#    ('ohe__cancer_1', -0.1767578747281952),
#    ('ohe__cancer_0', -0.14245171405625554),
#    ('ohe__arthritis_1', -0.1403819367971564),
#    ('ohe__stroke_1', -0.07566422536152054),
#    ('imp__in_cover_dur', 0.05785006329407156),
#    ('ohe__osteoporosis_0', 0.004020027693517975),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_6': {'y_pred': 9788.212826656685,
#   'shap_vals': [('imp__in_cover_amt', -20.92943371624365),
#    ('ohe__kidney_disease_0', 20.720304369175153),
#    ('ohe__heart_failure_0', 11.890566785091485),
#    ('ohe__pulmonary_disease_0', -6.649462515070624),
#    ('imp__drug_cover_dur', -5.89441030512184),
#    ('ohe__heart_failure_1', 4.763455389733065),
#    ('ohe__ischemic_heart_disease_0', 4.3891138116400015),
#    ('ohe__diabetes_0', 3.6105836075694486),
#    ('ohe__depression_0', 3.4223030816928195),
#    ('ohe__ischemic_heart_disease_1', 3.217765762404189),
#    ('ohe__diabetes_1', 2.9949742090462386),
#    ('ohe__kidney_disease_1', 2.223475985655643),
#    ('imp__age', 1.9032725893540103),
#    ('ohe__alzheimers_0', -1.5673493601599722),
#    ('imp__out_excess_amt', -1.2690370352831388),
#    ('ohe__arthritis_0', 0.9354481057720054),
#    ('ohe__depression_1', 0.9004054131674951),
#    ('ohe__stroke_0', -0.7458741809834318),
#    ('imp__in_excess_amt', -0.6529471207291194),
#    ('ohe__arthritis_1', 0.2947954111101422),
#    ('ohe__stroke_1', -0.2621074919532233),
#    ('imp__out_cover_amt', 0.20879523337343597),
#    ('ohe__cancer_0', -0.15917134596995303),
#    ('ohe__alzheimers_1', -0.1171155489843092),
#    ('ohe__pulmonary_disease_1', -0.10778854181245903),
#    ('imp__out_cover_dur', 0.0898960527364026),
#    ('ohe__cancer_1', -0.07470250144419444),
#    ('ohe__osteoporosis_0', 0.0030832908819829817),
#    ('imp__in_cover_dur', -0.0023612378405640537),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_7': {'y_pred': 3271.6081156756163,
#   'shap_vals': [('imp__in_cover_amt', -38.432666852691845),
#    ('ohe__kidney_disease_0', -10.235269447885903),
#    ('ohe__heart_failure_0', -9.33100469692607),
#    ('ohe__ischemic_heart_disease_0', -5.721383326603668),
#    ('imp__out_excess_amt', 4.198484338190175),
#    ('ohe__ischemic_heart_disease_1', -3.660857283972048),
#    ('ohe__diabetes_0', -3.6217200500897224),
#    ('imp__out_cover_amt', -3.1681079503574217),
#    ('ohe__heart_failure_1', -2.940039053680547),
#    ('ohe__pulmonary_disease_0', -2.8570063367900325),
#    ('ohe__diabetes_1', -2.810492970549614),
#    ('imp__drug_cover_dur', -2.2180274729356353),
#    ('ohe__alzheimers_0', -1.8913949939411798),
#    ('ohe__depression_0', -1.8906707660429276),
#    ('imp__age', -1.3461207293003266),
#    ('imp__in_excess_amt', -1.2192947608301457),
#    ('ohe__kidney_disease_1', -0.8772751968791456),
#    ('imp__out_cover_dur', 0.7441215241527736),
#    ('ohe__depression_1', -0.6221804908410961),
#    ('ohe__arthritis_0', -0.4572455159300638),
#    ('ohe__pulmonary_disease_1', -0.38671906191237604),
#    ('ohe__stroke_0', -0.3670111464621888),
#    ('ohe__cancer_1', -0.24064989536200862),
#    ('ohe__alzheimers_1', -0.2336799219715595),
#    ('ohe__cancer_0', -0.2207405749958681),
#    ('ohe__arthritis_1', -0.1785355512036479),
#    ('ohe__stroke_1', -0.10415125895902658),
#    ('ohe__osteoporosis_0', -0.01356831096178053),
#    ('imp__in_cover_dur', -0.011580519581192652),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_8': {'y_pred': 1036.263579169156,
#   'shap_vals': [('imp__in_cover_amt', -28.016203713529954),
#    ('imp__out_cover_amt', -19.605598742964098),
#    ('ohe__kidney_disease_0', -8.214916866300275),
#    ('ohe__heart_failure_0', -7.433995159301984),
#    ('ohe__ischemic_heart_disease_0', -5.5889961233820395),
#    ('imp__out_excess_amt', -3.9823504658851343),
#    ('ohe__ischemic_heart_disease_1', -3.966290183059673),
#    ('ohe__diabetes_0', -3.4764450831017557),
#    ('imp__out_cover_dur', -2.7917603883807063),
#    ('ohe__heart_failure_1', -2.6863541088004492),
#    ('ohe__diabetes_1', -2.6103056854174325),
#    ('ohe__pulmonary_disease_0', -2.1234736911957595),
#    ('imp__drug_cover_dur', -1.6673600899351315),
#    ('ohe__alzheimers_0', -1.6528416512218154),
#    ('ohe__depression_0', -1.5829506494345496),
#    ('imp__in_excess_amt', -0.8967305237239976),
#    ('ohe__kidney_disease_1', -0.750515892683684),
#    ('imp__age', -0.7471723846846525),
#    ('ohe__depression_1', -0.523931162644769),
#    ('ohe__arthritis_0', -0.3594056924952116),
#    ('ohe__stroke_0', -0.2676541537236171),
#    ('ohe__pulmonary_disease_1', -0.23105107264761512),
#    ('ohe__alzheimers_1', -0.22689988249181567),
#    ('ohe__cancer_1', -0.1764286657913456),
#    ('ohe__cancer_0', -0.14245171405625554),
#    ('ohe__arthritis_1', -0.1403819367971564),
#    ('ohe__stroke_1', -0.07566422536152054),
#    ('imp__in_cover_dur', 0.05785006329407156),
#    ('ohe__osteoporosis_0', 0.004020027693517975),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]},
#  'row_9': {'y_pred': 1358.2750541390149,
#   'shap_vals': [('imp__in_cover_amt', -28.75208075486991),
#    ('imp__out_cover_amt', -20.13696285046054),
#    ('ohe__kidney_disease_0', -9.032229510581539),
#    ('ohe__heart_failure_0', -7.763860694433242),
#    ('ohe__ischemic_heart_disease_0', -5.720631430901482),
#    ('imp__out_excess_amt', -4.1013824523328815),
#    ('ohe__ischemic_heart_disease_1', -3.917475235394268),
#    ('ohe__diabetes_0', -3.48761170244434),
#    ('ohe__heart_failure_1', -2.7388070512593465),
#    ('ohe__diabetes_1', -2.640618800144198),
#    ('ohe__pulmonary_disease_0', -2.172330040929419),
#    ('ohe__alzheimers_0', -1.7555393666745134),
#    ('ohe__depression_0', -1.5786640696716068),
#    ('imp__age', -1.1574638144653016),
#    ('imp__in_excess_amt', -0.9671906954870418),
#    ('ohe__kidney_disease_1', -0.8840157087908865),
#    ('ohe__depression_1', -0.5641121001007023),
#    ('imp__out_cover_dur', 0.558437971050413),
#    ('imp__drug_cover_dur', 0.4090606019312229),
#    ('ohe__arthritis_0', -0.34798097612039663),
#    ('ohe__stroke_0', -0.28745451534893945),
#    ('ohe__pulmonary_disease_1', -0.23709248461771812),
#    ('ohe__alzheimers_1', -0.234390107563636),
#    ('ohe__cancer_1', -0.1779173207364211),
#    ('ohe__cancer_0', -0.14332078540882423),
#    ('ohe__arthritis_1', -0.1294747094982597),
#    ('ohe__stroke_1', -0.08912377113492656),
#    ('imp__in_cover_dur', -0.008690787255473988),
#    ('ohe__osteoporosis_0', 0.006079690392552094),
#    ('ohe__sex_1', 0.0),
#    ('ohe__sex_2', 0.0),
#    ('ohe__osteoporosis_1', 0.0),
#    ('imp__carrier_cover_dur', 0.0)]}}
